# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit

# %%
print(1+1)
# Out:
# 2

# %%
import importlib
import calib
importlib.reload(calib)
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')  # Adjust if the module path is different

# Set experiment name and filetype
exp_name = "merq"
filetype = ".txt"

# Call the function to read the files
file_contents = calib.read_files(exp_name, filetype)

# %%
plt.figure(figsize=(10, 6))

# Loop through the file contents to plot each file
for file_path, data in file_contents.items():
    # Extract time (x) and value (y) from the data
    time = [point[0] for point in data]  # Wavelength in Angstroms
    value = [point[1] for point in data]  # Intensity

    # Plot the data for the current file
    plt.plot(time, value, label=file_path.split('/')[-1])  # Extract just the file name for the legend

# Add labels and title
plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {exp_name}')

# Add a legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
import importlib
import calib
importlib.reload(calib)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

# Set experiment name and filetype
exp_name = "merq"
filetype = ".txt"

# Call the function to fit the Gaussians and calculate the average mean
average_mean = calib.fit_gaussian_and_calculate_mean(exp_name, filetype)


print(f"difrence from expected is: {calib.round_sf(5460.74-average_mean,3)}")
# Out:
# Average mean of the Gaussian fits: 5458.10546321963
# difrence from expected is: 2.63

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))

# Loop through the file contents to plot each file
for file_path, data in file_contents.items():
    # Extract time (x) and value (y) from the data
    time = [point[0] for point in data]  # Wavelength in Angstroms
    value = [point[1] for point in data]  # Intensity

    # Plot the data for the current file
    plt.plot(time, value, label=file_path.split('/')[-1])  # Extract just the file name for the legend

# Add labels and title
plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {exp_name}')

# Add a legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('hydr_full.txt')

plt.figure(figsize=(10, 6))

# Loop through the file contents to plot each file
for file_path, data in file_contents.items():
    # Extract time (x) and value (y) from the data
    time = [point[0] for point in data]  # Wavelength in Angstroms
    value = [point[1] for point in data]  # Intensity

    # Plot the data for the current file
    plt.plot(time, value, label=file_path.split('/')[-1])  # Extract just the file name for the legend

# Add labels and title
plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {exp_name}')

# Add a legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()
