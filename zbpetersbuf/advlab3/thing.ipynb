# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import linregress
import math

# %%
#print(0.75+13.75+4+16+14+2)
print(50.5+16+14+3)
# Out:
# 83.5

# %%
import importlib
import calib
importlib.reload(calib)
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
exp_name = "merq"
filetype = ".txt"
file_contents = calib.read_files(exp_name, filetype)

# %%
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('count number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs count number for {exp_name}')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

i=0

for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    if i == 0:
        plt.plot(time, value, label="Mercury run 1")
    if i == 1:
        plt.plot(time, value, label="Mercury run 2")
    if i == 2:
        plt.plot(time, value, label="Mercury run 3")
    if i == 3:
        plt.plot(time, value, label="Mercury run 4")
    
    i+=1



plt.xlabel('count number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Count Number for Mercury')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import calib
importlib.reload(calib)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
exp_name = "merq"
filetype = ".txt"
average_mean = calib.fit_gaussian_and_calculate_mean(exp_name, filetype)
print(f"difrence from expected is: {calib.round_sf(5460.74-average_mean,3)}")
# Out:
# Average mean of the Gaussian fits: 5458.10546321963
# difrence from expected is: 2.63

# %%
import importlib
import calib
importlib.reload(calib)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
exp_name = "merq"
filetype = ".txt"
average_mean = calib.fit_gaussian_and_calculate_sigma_v2(exp_name, filetype)


#print(f"difrence from expected is: {calib.round_sf(5460.74-average_mean,3)}")
# Out:
# Average sigma of the Gaussian fits: 4.824102678573427

# %%
print(4.8*(5)**(-1/2))
print(0.98*2.1)
# Out:
# 2.146625258399798
# 2.058

# %%
print(4.8 * 2 * (2 * math.log(2))**(1/2))
print(4.8*2.4)
# Out:
# 11.303136216148557
# 11.52

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_delay.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label='Mercury recording')

plt.xlabel('Count Number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Count Number for Mercury, Determining Response Time')
plt.legend()

plt.grid(True)
#plt.grid(True, which='major', linestyle='--', color='black', linewidth=0.75)
#plt.minorticks_on()
#plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
#plt.xlim(5455, 5465)
#plt.ylim(6200, 7000)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_delay.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label='Mercury recording')


zro = np.zeros(242)

zro = [-0.02+x for x in zro]

plt.plot(time, zro, label='1/3 of Max Intencity')




plt.xlabel('Count Number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Count Number for Mercury, Determining Response Time (zoomed in)')
plt.legend()
plt.grid(True, which='major', linestyle='--', color='black', linewidth=0.75)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.xlim(5455, 5465)
#plt.ylim(6200, 7000)
plt.show()

# %%
print((0.12+0.09)/3 + -0.09)
print((5459.4-5459.75)*0.6)
print (0.6*100/60)
print(11/(0.63))
print(17*60)
# Out:
# -0.020000000000000004
# -0.21000000000021826
# 1.0
# 17.46031746031746
# 1020

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Count Number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Count Number for {'merq_full'}')
plt.legend()
plt.grid(True)

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label='Mercury recording')

plt.xlabel('Count Number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Count Number for Mercury')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import calib
importlib.reload(calib)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
print(calib.max_y_in_range(data,3800,3804))
print(calib.max_y_in_range(data,4145,4185))
print(calib.max_y_in_range(data,4300,4500))
print(calib.max_y_in_range(data,5000,5500))
# Out:
# (3800.755, 0.391)
# (4166.38, 0.186)
# (4451.537, 0.661)
# (5460.155, 0.191)

# %%
import importlib
import calib
importlib.reload(calib)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
print(calib.fit_gaussian(data, 3780, 3830))
print(calib.fit_gaussian(data, 4145, 4185))
print(calib.fit_gaussian(data, 4420, 4480))
print(calib.fit_gaussian(data, 5430, 5490))
# Out:
# (np.float64(3801.350792399504), np.float64(0.021219942884681913))
# (np.float64(4165.944201897609), np.float64(0.011214502352266696))
# (np.float64(4451.494295892367), np.float64(0.009845838354548341))
# (np.float64(5460.028240590105), np.float64(0.00910370905348803))

# %%
call_data = [(3801.35, 3806.312), (4165.94, 4120.440), (4451.49, 4398.617), (5460.03, 5425.253)]

x_vals, y_vals = zip(*call_data)
slope, intercept, r_value, p_value, std_err = linregress(x_vals, y_vals)

print(f"Linear Fit Equation: y = {slope:.5f}x + {intercept:.5f}")

plt.plot(x_vals, y_vals, 'o', label='Data Points')
#plt.plot(x_vals, [slope * x + intercept for x in x_vals], label=f'Fit: Angstroms = 0.98 (recorded $\mathrm{\AA}$) + 35.50')
plt.plot(x_vals, [slope * x + intercept for x in x_vals], 
         label=f'Fit: Accepted values $\mathrm{{\AA}}$ = {slope:.2f} (recorded $\mathrm{{\AA}}$) + {intercept:.2f}')



plt.xlabel('Recorded Count Number')
plt.ylabel('Accepted Wavelengths [Angstroms]')
plt.title('Calabration Curve of Hg Spectra')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Linear Fit Equation: y = 0.98489x + 35.50471

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label='Mercury recording')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Applied Calibration, Intensity vs Wavelength for the Spectra of Hg')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('hydr_full.txt')
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label='Hydrogen recording')

plt.xlabel('Wavelength [Angstroms]')
plt.ylabel('Intensity')
plt.title(f'Applied Calibration, Intensity vs Wavelength for the Spectra of Hydrogen')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('hydr_full.txt')
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])




plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'hydr_full'}')


plt.xlim(3950, 4000)


plt.legend()
plt.grid(True)
plt.show()

# %%
data = [(x, y) for x, y in zip(time, value)]

a1 = calib.fit_gaussian(data, 3950, 4000)[0]
print(a1)
a2 = calib.fit_gaussian(data, 4020, 4070)[0]
print(a2)
a3 = calib.fit_gaussian(data, 4150, 4200)[0]
print(a3)
a4 = calib.fit_gaussian(data, 4350, 4450)[0]
print(a4)
a5 = calib.fit_gaussian(data, 4800, 5000)[0]
print(a5)
a6 = calib.fit_gaussian(data, 6400, 6600)[0]
print(a6)
# Out:
# 3976.736936583479
# 4049.95748878339
# 4168.107424839995
# 4382.337815743603
# 4850.187551857827
# 6518.842645237036

# %%
b1 = calib.fit_gaussian(data, 4000, 4101)[1] 
print(b1)
b2 = calib.fit_gaussian(data, 4100, 4202)[1] 
print(b2)
b3 = calib.fit_gaussian(data, 4200, 4300)[1] 
print(b3)
b4 = calib.fit_gaussian(data, 4400, 4500)[1] 
print(b4)
b5 = calib.fit_gaussian(data, 4890, 5000)[1]
print(b5)
b6 = calib.fit_gaussian(data, 6400, 6600)[1]
# Out:
# 0.05168923730911409
# 0.01727065963489886
# inf
# inf
# 2.1723852432330624
# /workspaces/CP1-24-final/zbpetersbuf/advlab3/calib.py:180: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(gaussian, x_data, y_data, p0=[A_guess, mu_guess, sigma_guess, c_guess])

# %%
def rydform(n1,n2):
    Rm = 10973731.6
    return 10**10/(Rm*(1/n2**(2)-1/n1**(2)))

print(rydform(5,2))
# Out:
# 4339.366894944616

# %%
print((10973731.6-10260000)/10973731.6)
# Out:
# 0.06504000881523288

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given y_vals and x_vals
y_vals = [1/(y*10**(-10)) for y in [a1, a2, a3, a4, a5, a6]]  # Use your values for a1, a2, etc.
x_vals = [x**(-2) for x in [8, 7, 6, 5, 4, 3]]  # As per your data

# Define the linear model (Rydberg equation)
def ry_lin_from(x, R_m, c):
    return R_m * (1/4 - x) + c

# Fit the data to the model
popt, pcov = curve_fit(ry_lin_from, x_vals, y_vals, p0=[1, 1])

# Extract fitted parameters
R_m_fit, c_fit = popt

# Calculate fitted values
y_fit = ry_lin_from(np.array(x_vals), *popt)

# Calculate residuals
residuals = y_vals - y_fit

# Calculate R-squared
ss_res = np.sum(residuals**2)  # Residual sum of squares
ss_tot = np.sum((y_vals - np.mean(y_vals))**2)  # Total sum of squares
r_squared = 1 - (ss_res / ss_tot)

# Calculate Adjusted R-squared
n = len(y_vals)  # Number of data points
p = len(popt)  # Number of parameters (2: R_m and c)
r_squared_adj = 1 - (1 - r_squared) * (n - 1) / (n - p - 1)

# Print fitted parameters and errors
R_m_error = np.sqrt(pcov[0, 0])
c_error = np.sqrt(pcov[1, 1])

print(f"Fitted R_m: {R_m_fit} ± {R_m_error}")
print(f"Fitted c: {c_fit} ± {c_error}")
print(f"R-squared: {r_squared}")
print(f"Adjusted R-squared: {r_squared_adj}")

# Plot the data and the fit
plt.plot(x_vals, y_vals, 'o', label='Data Points')
#plt.plot(x_vals, y_fit,label=(f'Fit: y = 10260000(1/4 - x) + 120000\n'f'$R^2 = {r_squared:.3f}$, $Adj\\ R^2 = {r_squared_adj:.3f}$'))

plt.plot(x_vals, y_fit,label=(f'Fit: y = 10260000(1/4 - x) + 120000\n'f'$R^2 = 1.0$, $Adj\\ R^2 = 1.0$'))


plt.xlabel(r'1 over the square of the quantum number $n_1^{-2}$')  # Label for x-axis
plt.ylabel(r'Inverse Wavelength, $\lambda^{-1}$ [1/$\mathrm{\AA}$]')  # Label for y-axis

# Title and legend
plt.title('Rydberg formula, for the Balmer series')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# Fitted R_m: 10256126.267906668 ± 157496.04430959045
# Fitted c: 120286.73874250383 ± 32505.110381919698
# R-squared: 0.9990576262629209
# Adjusted R-squared: 0.9984293771048682

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('heli_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label='Helium recording')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Applied Calibration, Intensity vs Wavelength for the Spectra of Helium')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('heli_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])


plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'heli_full'}')
plt.xlim(3900,4050)
plt.legend()
plt.grid(True)
plt.show()

# %%
data = [(x, y) for x, y in zip(time, value)]
he1 = calib.fit_gaussian(data, 3920, 4020)[0]
print(he1)
he2 = calib.fit_gaussian(data, 4520, 4575)[0]
print(he2)
he3 = calib.fit_gaussian(data, 5010, 5063)[0]
print(he3)
he4 = calib.fit_gaussian(data, 5770, 5860)[0]
print(he4)
# Out:
# 3976.017426708717
# 4553.580485593293
# 5046.497882588566
# 5827.381611578775

# %%
b1 = calib.fit_gaussian(data, 3980, 4050)[1]
print(b1)
b2 = calib.fit_gaussian(data, 4520, 4575)[1]
print(b2)
b3 = calib.fit_gaussian(data, 5010, 5063)[1]
print(b3)
b4 = calib.fit_gaussian(data, 5770, 5860)[1]
print(b4)
# Out:
# 0.8741862203742383
# 0.405635824546251
# 1.3125878676723843
# 6.034527929169674

# %%
s_p = [-0.9138+3.62329,-0.9934+3.6232,-0.9934+3.6233,-1.6671+3.62329,-1.8689+3.6232,-1.8689+3.6233]
p4_3d = [-0.879483+1.513732,-0.879496+1.513738,-0.879497+1.513732,-0.879497+1.513738]
d4_3p = [-0.851298+1.580316,-0.851298+1.580313,-0.851298+1.580279,-0.851054+1.580313]
d4_2p = [-0.851298+3.623302, -0.851298+3.623292, -0.851298+3.623170, -0.851054+3.623292, -0.851054+3.369366, -0.851298+3.369366]
d3_2p = [-1.513738+3.623302,-1.513738+3.623292,-1.513738+3.369366,-1.513732+3.623302,-1.513732+3.623170,-1.513314+3.623292,-1.513314+3.369366]
p4_2s = [-0.879497+4.767774,-0.879496+3.971614,-0.879483+4.767774]
p3_2s = [-1.500370+3.971614]
p2_2s = [-3.623302+4.767774,-3.623292+3.971614,-3.623170+4.767774,-3.369366+3.971614]

s4_3p = [-0.913818+1.500370]

def find_wave(eV):
    return (4.135*2.997/(eV))*10**(8-15+9)
    #return (6.6*3/(eV))*10**(8-16+9)

print([find_wave(x) for x in s_p])
#print([find_wave(x) for x in p4_3d])
#print([find_wave(x) for x in d4_3p])
print([find_wave(x) for x in d4_2p])
print([find_wave(x) for x in d3_2p])
print([find_wave(x) for x in p4_2s])
print([find_wave(x) for x in p3_2s])
#print([find_wave(x) for x in p2_2s])
#print([find_wave(x) for x in s4_3p])
print(find_wave(-3.036780+5.139077))
# Out:
# [457.37740312752584, 471.2371663244352, 471.21924788014746, 633.5067145829393, 706.4125292139313, 706.3722640218878]
# [447.06266657623866, 447.06427935991195, 447.08395625772033, 447.024930759913, 492.09927125789017, 492.14695552304374]
# [587.4481646444478, 587.4509493475871, 667.8383275096086, 587.4464938352365, 587.4832538334855, 587.3329011013384, 667.6857652695074]
# [318.71687639538015, 400.7801448715734, 318.71572883819647]
# [501.4719307360988]
# 589.478793909709

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label='Sodium recording')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Applied Calibration, Intensity vs Wavelength for the Spectra of Sodium')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label='Sodium recording')


plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Applied Calibration, Intensity vs Wavelength for the Spectra of Sodium')

#plt.xlim(4800,5600)

plt.xlim(5500,6000)


plt.legend()
plt.grid(True, which='major', linestyle='--', color='black', linewidth=0.75)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import calib
importlib.reload(calib)

data = [(x, y) for x, y in zip(time, value)]
#Na = 0.98*calib.fit_gaussian(data, 5700, 5850)[0] + 35.5

Na_1 = calib.fit_gaussian(data, 5550, 5625)[0]

print(Na_1)
# Out:
# 5588.729357921909

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_twin.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label='Sodium twin recording')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Applied Calibration, Intensity vs Wavelength for the Spectra of Sodium')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_twin.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Applied Calibration, Intensity vs Wavelength for the Spectra of Sodium')

#plt.xlim(5765,5790)
plt.xlim(5770,5785)

plt.legend()
plt.grid(True, which='major', linestyle='--', color='black', linewidth=0.75)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)
import two_peak
importlib.reload(two_peak)
import calib
importlib.reload(calib)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_twin.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])


fit_parameters = two_peak.fit_twin_gaussian(time, value, 5790, 5825)
plt.plot(time, two_peak.twin_gaussian(time, *fit_parameters), color = 'Black', label="fit", linestyle='-')

#plt.plot(time, calib.gaussian(time, fit_parameters[0], fit_parameters[1], fit_parameters[2], fit_parameters[6]), color='Red',
# label=f'Peak 1 {calib.round_sf(fit_parameters[1],5)}', linestyle='--')
#plt.plot(time, calib.gaussian(time, fit_parameters[3], fit_parameters[4], fit_parameters[5], fit_parameters[6]), color='Blue',
# label=f'Peak 2, center = {calib.round_sf(fit_parameters[4],5)} A', linestyle='--')

plt.plot(time, calib.gaussian(time, fit_parameters[0], fit_parameters[1], fit_parameters[2], fit_parameters[6]), color='Red',
         label=f'Peak 1, center = {calib.round_sf(fit_parameters[1], 5)} $\mathrm{{\AA}}$', linestyle='--')

plt.plot(time, calib.gaussian(time, fit_parameters[3], fit_parameters[4], fit_parameters[5], fit_parameters[6]), color='Blue',
         label=f'Peak 2, center = {calib.round_sf(fit_parameters[4], 5)} $\mathrm{{\AA}}$', linestyle='--')


plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'sodium_twin'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quartzbulb_no_I2.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label='Tungsten Halogen lamp recording')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')


plt.title('Applied Calibration, Intensity vs Wavelength for the Tungsten Halogen lamp, no Iodine')


plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=r'Tungsten Halogen lamp, with $I_2$')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')

plt.title('Applied Calibration, Intensity vs Wavelength for the Tungsten Halogen lamp, with Iodine')

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('output.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'output'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=r'$I_2$ with wiggle')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Slope of Intensity by Wavelength [dI/dλ]')


plt.title('Applied Calibration, dI/dλ vs Wavelength for the Tungsten Halogen lamp, with Iodine')


plt.legend()
plt.grid(True)
plt.show()

# %%
xmin = 5100
xmax = 6200
# window_length=2000, polyorder=3
wl = 2000
pol = 3

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

x_avg_start = 100
bin_width = 5

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([0.98*point[0] + 35.5 for point in data])
    intensity = np.array([point[1] for point in data])
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)
    plt.plot(wavelength, intensity, label=r'$I_2$ with wiggle')
    plt.plot(wavelength, smooth_intensity, color='orange', linewidth=1, label='Savitzky-Golay filter')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Slope of Intensity by Wavelength [dI/dλ]')
plt.title('Applied Calibration, dI/dλ vs Wavelength for the Tungsten Halogen lamp, with Iodine')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([0.98*point[0] + 35.5 for point in data])
    intensity = np.array([point[1] for point in data])

    # Apply Savitzky-Golay filter
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)

    # Detrended data = original - smoothed
    detrended_intensity = intensity - smooth_intensity

    # Plot detrended data
    plt.plot(wavelength, detrended_intensity, label=r'$I_2$ with wiggle - Savitzky-Golay filter')

plt.xlabel('Wavelength (Angstroms)')


plt.ylabel('dI/dλ  subtracted by Savitzky-Golay filter [dI/dλ]')




plt.title('(dI/dλ - Savitzky-Golay filter) vs Wavelength for the Tungsten Halogen lamp, with Iodine')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = absospec.read_files('I2_wiggle.txt')
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([0.98*point[0] + 35.5 for point in data])
    intensity = np.array([point[1] for point in data])
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)
    detrended_intensity = intensity - smooth_intensity

    #plt.plot(wavelength, detrended_intensity, label=r'$I_2$ with wiggle - Savitzky-Golay filter')
    plt.plot(wavelength, detrended_intensity, label=r'$I_2$ with wiggle - Savitzky-Golay filter')

    # Legend with custom location and opacity
    


plt.xlabel('Wavelength (Angstroms)')

plt.ylabel('dI/dλ  subtracted by Savitzky-Golay filter [dI/dλ]')

plt.title('(dI/dλ - Savitzky-Golay filter) vs Wavelength for the Tungsten Halogen lamp, with Iodine')

#plt.xlim(xmin, xmax)
#plt.ylim(-1.5, 1.5)

plt.xlim(5360, 5400)
#plt.ylim(-0.6, 0.5)


plt.legend(loc='upper right', framealpha=1)
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
print(((2* 10**(-8) / (6052 * 10**(-8))**2)**2 + (2 * 10**(-8)/ (6015 * 10**(-8))**2)**2 )**(1/2))
# Out:
# 7.770102976903843

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 7
v = np.arange(x,x+35)

w_e, x_e, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)

lamdas = [5172, 5186, 5200, 5215, 5230, 5245, 5261, 5278, 5296, 5314, 5333, 5352, 5373, 5394, 5415, 5439, 5464, 5490,
          5515, 5541, 5568, 5595, 5623, 5651, 5682, 5712, 5743, 5775, 5807, 5840, 5873, 5908, 5943, 5980, 6015, 6052]
lamdas = lamdas[::-1]

v_fit = np.linspace(min(v), max(v), 200)
G_fit = Birge_Sponer.fit_BS_v2(v_fit, w_e, x_e)

print(f"Linear Fit Equation: delta_G = {w_e:.5f} - 2 * {w_e:.5f}*{x_e:.5f}*(v+1)")
plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label=f'{w_e:.5f} - 2 * {w_e:.5f}*{x_e:.5f}*(v+1)', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()

print(f"w_e = {w_e:.2f}, x_e = {x_e:.4f}, w_e*x_e = {w_e*x_e:.4f}")
v_m = 0.5*w_e-1
print(f"v_m = {v_m:.2f}")
G = w_e*(v_m+1/2)-w_e*x_e*((v_m+1/2)**(2))
print(f"equation 7 = {G:.2f}")
# Out:
# Linear Fit Equation: delta_G = 121.78625 - 2 * 121.78625*0.00655*(v+1)
# w_e = 121.79, x_e = 0.0065, w_e*x_e = 0.7973
# v_m = 59.89
# equation 7 = 4447.00

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys


last_wiggle_G = - 1 / (6052 * 10**(-8)) + 1 / (6015 * 10**(-8))



print(Birge_Sponer.fit_BS_v2(x,w_e,x_e))
print(last_wiggle_G)

v_00 = Birge_Sponer.fit_BS_v2(x+35,w_e,x_e)

print(f"v_00 = {v_00:.2f}")

print(f"v_00 = {1 / (6052 * 10**(-8)):.2f}")
# Out:
# 107.43469152705859
# 101.64058898798612
# v_00 = 51.62
# v_00 = 16523.46

# %%
D_dubprim = 16361.26 + 5336.61 - 7589

print(f"D_dubprim = {D_dubprim:.9f}")
# Out:
# D_dubprim = 14108.870000000

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys
import numpy as np
import matplotlib.pyplot as plt

x = 7
v = np.arange(x, x + 35)

w_e, x_e, w_e_err, x_e_err, G_v = Birge_Sponer.Birge_Sponer_funk_v4(v)

lamdas = [5172, 5186, 5200, 5215, 5230, 5245, 5261, 5278, 5296, 5314, 5333, 5352, 5373, 5394, 5415, 5439, 5464, 5490,
          5515, 5541, 5568, 5595, 5623, 5651, 5682, 5712, 5743, 5775, 5807, 5840, 5873, 5908, 5943, 5980, 6015, 6052]
lamdas = lamdas[::-1]

v_fit = np.linspace(min(v), max(v), 200)
G_fit = Birge_Sponer.fit_BS_v2(v_fit, w_e, x_e)

# Fit equation display
print(f"Linear Fit Equation: delta_G = {w_e:.5f} - 2 * {w_e:.5f}*{x_e:.5f}*(v+1)")




G_v_fit = Birge_Sponer.fit_BS_v2(v, w_e, x_e)  # predicted values at original v points
residuals = G_v - G_v_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((G_v - np.mean(G_v))**2)
r_squared = 1 - (ss_res / ss_tot)
adj_r_squared = 1 - (1 - r_squared) * (len(G_v) - 1) / (len(G_v) - 2)  # 2 params

# Fit equation with R² values in legend
#fit_label = (f'{w_e:.5f} - 2×{w_e:.5f}×{x_e:.5f}×(v+1)\n'f'$R^2$ = {r_squared:.5f},  Adj $R^2$ = {adj_r_squared:.5f}')

fit_label = (f'122 - 2×122×{x_e:.5f}×(v+1)\n'f'$R^2$ = 0.95,  Adj $R^2$ = 0.95')




# Plot
plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label=fit_label, color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title(r'Birge-Sponer Plot for $I_2$')

#plt.legend()
plt.legend(loc='upper right', framealpha=1)


plt.grid(True)
plt.show()


# Parameter outputs with uncertainties
print(f"w_e = {w_e:.2f} ± {w_e_err:.2f}")
print(f"x_e = {x_e:.5f} ± {x_e_err:.5f}")
we_xe = w_e * x_e
we_xe_err = np.sqrt((x_e * w_e_err)**2 + (w_e * x_e_err)**2)
print(f"w_e * x_e = {we_xe:.4f} ± {we_xe_err:.4f}")

# v_m and G(v_m) (equation 7)
v_m = 0.5 * w_e - 1
v_m_err = 0.5 * w_e_err
print(f"v_m = {v_m:.2f} ± {v_m_err:.2f}")

G = w_e * (v_m + 0.5) - w_e * x_e * (v_m + 0.5)**2
# Error propagation
dG_dw = (v_m + 0.5) - x_e * (v_m + 0.5)**2
dG_dx = -w_e * (v_m + 0.5)**2
G_err = np.sqrt((dG_dw * w_e_err)**2 + (dG_dx * x_e_err)**2)
print(f"equation 7 = {G:.2f} ± {G_err:.2f}")


v_00 =   1 / (6052 * 10**(-8)) 
D_o = w_e*(v_m+1/2)-w_e*x_e*(v_m+0.5)**2
D_dubprim = D_o + v_00 - 7589

print(f"D_singprim = {D_o:.9f}")
print(f"D_dubprim = {D_dubprim:.9f}")
# Out:
# Linear Fit Equation: delta_G = 121.78625 - 2 * 121.78625*0.00655*(v+1)
# w_e = 121.79 ± 1.71
# x_e = 0.00655 ± 0.00017
# w_e * x_e = 0.7973 ± 0.0234
# v_m = 59.89 ± 0.85
# equation 7 = 4447.00 ± 97.47
# D_singprim = 4447.004415363
# D_dubprim = 13381.467733274

# %%
v_00 =   1 / (6052 * 10**(-8)) 
D_o = w_e*(v_m+1/2)-w_e*x_e*(v_m+0.5)**2
D_dubprim = D_o + v_00 - 7589
D_o_err = G_err
D_dubprim_err = D_o_err

print(f"D_singprim = {D_o:.9f} ± {D_o_err:.9f}")
print(f"D_dubprim = {D_dubprim:.9f} ± {D_dubprim_err:.9f}")
# Out:
# D_singprim = 4447.004415363 ± 97.470774744
# D_dubprim = 13381.467733274 ± 97.470774744

# %%
D_o = w_e*(v_m+1/2)-w_e*x_e*(v_m+0.5)**2

# %%
D_dubprim = D_o + 1 / (6052 * 10**(-8)) - 7589
print(f"D_singprim = {D_o:.9f}")
print(f"D_dubprim = {D_dubprim:.9f}")
# Out:
# D_singprim = 4447.004415363
# D_dubprim = 13381.467733274

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys
import numpy as np
import matplotlib.pyplot as plt

x = 7
v = np.arange(x, x + 35)

w_e, x_e, w_e_err, x_e_err, G_v = Birge_Sponer.Birge_Sponer_funk_v4(v)

lamdas = [5172, 5186, 5200, 5215, 5230, 5245, 5261, 5278, 5296, 5314, 5333, 5352, 5373, 5394, 5415, 5439, 5464, 5490,
          5515, 5541, 5568, 5595, 5623, 5651, 5682, 5712, 5743, 5775, 5807, 5840, 5873, 5908, 5943, 5980, 6015, 6052]
lamdas = lamdas[::-1]

v_fit = np.linspace(min(v), max(v), 200)
G_fit = Birge_Sponer.fit_BS_v2(v_fit, w_e, x_e)

# Fit equation display
print(f"Linear Fit Equation: delta_G = {w_e:.5f} - 2 * {w_e:.5f}*{x_e:.5f}*(v+1)")




G_v_fit = Birge_Sponer.fit_BS_v2(v, w_e, x_e)  # predicted values at original v points
residuals = G_v - G_v_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((G_v - np.mean(G_v))**2)
r_squared = 1 - (ss_res / ss_tot)
adj_r_squared = 1 - (1 - r_squared) * (len(G_v) - 1) / (len(G_v) - 2)  # 2 params

# Fit equation with R² values in legend
#fit_label = (f'{w_e:.5f} - 2×{w_e:.5f}×{x_e:.5f}×(v+1)\n'f'$R^2$ = {r_squared:.5f},  Adj $R^2$ = {adj_r_squared:.5f}')

#fit_label = (f'Fit: Δ G( ν ')122 - 2×122×{x_e:.5f}×(v+1)\n'f'$R^2$ = 0.95,  Adj $R^2$ = 0.95')

fit_label = (f"Fit: ΔG(ν′) = 122 - 1.6(ν′+1)\n"f"$R^2$ = 0.95,  Adj $R^2$ = 0.95")


# Plot
plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label=fit_label, color='orange')
plt.xlabel('Vibrational Quantum Number ν′')
plt.ylabel('ΔG(ν′) [cm⁻¹]')
plt.title(r'Birge-Sponer Plot for $I_2$')

#plt.legend()
plt.legend(loc='upper right', framealpha=1)


plt.grid(True)
plt.show()
# Out:
# Linear Fit Equation: delta_G = 121.78625 - 2 * 121.78625*0.00655*(v+1)

# %%
print(2 * 121.78625*0.00655)
# Out:
# 1.595399875

# %%
print(2.27/(10/0.1))
# Out:
# 0.0227

# %%
print(0.0227/(2**(1/2)))
# Out:
# 0.016051323932934628
