# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import linregress

# %%
print(1+1)
# Out:
# 2

# %%
import importlib
import calib
importlib.reload(calib)
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
exp_name = "merq"
filetype = ".txt"
file_contents = calib.read_files(exp_name, filetype)

# %%
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('count number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs count number for {exp_name}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import calib
importlib.reload(calib)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
exp_name = "merq"
filetype = ".txt"
average_mean = calib.fit_gaussian_and_calculate_mean(exp_name, filetype)
print(f"difrence from expected is: {calib.round_sf(5460.74-average_mean,3)}")
# Out:
# Average mean of the Gaussian fits: 5458.10546321963
# difrence from expected is: 2.63

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_delay.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('count number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs count number for {'merq_delay'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('count number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs count number for {'merq_full'}')
plt.legend()
plt.grid(True)

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('count number')
plt.ylabel('Intensity')
plt.title(f'Intensity vs count number for {'merq_full'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import calib
importlib.reload(calib)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
print(calib.max_y_in_range(data,3800,3804))
print(calib.max_y_in_range(data,4145,4185))
print(calib.max_y_in_range(data,4300,4500))
print(calib.max_y_in_range(data,5000,5500))
# Out:
# (3800.755, 0.391)
# (4166.38, 0.186)
# (4451.537, 0.661)
# (5460.155, 0.191)

# %%
print(calib.fit_gaussian(data, 3780, 3830))
print(calib.fit_gaussian(data, 4145, 4185))
print(calib.fit_gaussian(data, 4420, 4480))
print(calib.fit_gaussian(data, 5430, 5490))
# Out:
# 3801.350792399504
# 4165.944201897609
# 4451.494295892367
# 5460.028240590105

# %%
call_data = [(3801.35, 3806.312), (4165.94, 4120.440), (4451.49, 4398.617), (5460.03, 5425.253)]

x_vals, y_vals = zip(*call_data)
slope, intercept, r_value, p_value, std_err = linregress(x_vals, y_vals)

print(f"Linear Fit Equation: y = {slope:.3f}x + {intercept:.3f}")

plt.plot(x_vals, y_vals, 'o', label='Data Points')
plt.plot(x_vals, [slope * x + intercept for x in x_vals], label=f'Fit: y = {slope:.3f}x + {intercept:.3f}')

plt.xlabel('Measured Angstroms')
plt.ylabel('Expected Angstroms')
plt.title('calabration curve')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Linear Fit Equation: y = 0.985x + 35.505

# %%
import importlib
import spectrum
importlib.reload(spectrum)
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('merq_full.txt')

plt.figure(figsize=(10, 6))
for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'merq_full'}, applied fit')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('hydr_full.txt')
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'hydr_full'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')
file_contents = spectrum.read_files('hydr_full.txt')
plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]
    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'hydr_full'}')
plt.xlim(6200, 7000)
plt.legend()
plt.grid(True)
plt.show()

# %%
a1 = 0.99*calib.fit_gaussian(data, 4000, 4100) + 35.505
print(a1)
a2 = 0.99*calib.fit_gaussian(data, 4100, 4200) + 35.505
print(a2)
a3 = 0.99*calib.fit_gaussian(data, 4200, 4300) + 35.505
print(a3)
a4 = 0.99*calib.fit_gaussian(data, 4400, 4500) + 35.505
print(a4)
a5 = 0.99*calib.fit_gaussian(data, 4900, 5000) + 35.505
print(a5)
a6 = 0.99*calib.fit_gaussian(data, 6400, 6600) + 35.505
print(a6)
# Out:
# 4034.592738108084
# 4154.423949297974
# 4210.2823272993455
# 4426.69830535436
# 4954.927883830106
# 6436.398554882569

# %%
def rydform(n1,n2):
    Rm = 10973731.6
    return 10**10/(Rm*(1/n2**(2)-1/n1**(2)))

print(rydform(5,2))
# Out:
# 4339.366894944616

# %%
y_vals =[a1,a2,a3,a4,a5,a6]
y_vals =[1/(y*10**(-10)) for y in y_vals]
x_vals =[8,7,6,5,4,3]
x_vals =[x**(-2) for x in x_vals]


def ry_lin_from(x, R_m, c):
    return R_m * (1/4 - x) + c


popt, _ = curve_fit(ry_lin_from, x_vals, y_vals, p0=[1, 1])

R_m_fit, c_fit = popt
print(f"Linear Fit Equation: y = {calib.round_sf(R_m_fit,3)}(1/4 - x) + {calib.round_sf(c_fit,3)}")
plt.plot(x_vals, y_vals, 'o', label='Data Points')
plt.plot(x_vals, ry_lin_from(np.array(x_vals), R_m_fit, c_fit), label=f'Fit: y = {calib.round_sf(R_m_fit,3)}(1/4 - x) + {calib.round_sf(c_fit,3)}')

plt.xlabel('n_1^(-2)')
plt.ylabel('1/lamda')
plt.title('Rydberg formula, Balmer series')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Linear Fit Equation: y = 9660000.0(1/4 - x) + 214000.0

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('heli_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'heli_full'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('heli_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'heli_full'}')
plt.xlim(3990,5900)
plt.legend()
plt.grid(True)
plt.show()

# %%
he1 = 0.99*calib.fit_gaussian(data, 3980, 4050) + 35.5
print(he1)

he1_1 = 0.99*calib.fit_gaussian(data, 4110, 4170) + 35.5
#print(he1_1)

he2 = 0.99*calib.fit_gaussian(data, 4520, 4575) + 35.5
print(he2)


he2_1 = 0.99*calib.fit_gaussian(data, 4730, 4800) + 35.5
#print(he2_1)
he2_1 = 0.99*calib.fit_gaussian(data, 4930,4980) + 35.5
#print(he2_1)



he3 = 0.99*calib.fit_gaussian(data, 5010, 5063) + 35.5
print(he3)
he4 = 0.99*calib.fit_gaussian(data, 5770, 5860) + 35.5
print(he4)
# Out:
# 4036.972512282906
# 4545.262567054076
# 5038.327684713809
# 5815.766269164638

# %%
s_p = [-0.9138+3.62329,-0.9934+3.6232,-0.9934+3.6233,-1.6671+3.62329,-1.8689+3.6232,-1.8689+3.6233]
p4_3d = [-0.879483+1.513732,-0.879496+1.513738,-0.879497+1.513732,-0.879497+1.513738]
d4_3p = [-0.851298+1.580316,-0.851298+1.580313,-0.851298+1.580279,-0.851054+1.580313]
d4_2p = [-0.851298+3.623302, -0.851298+3.623292, -0.851298+3.623170, -0.851054+3.623292, -0.851054+3.369366, -0.851298+3.369366]
d3_2p = [-1.513738+3.623302,-1.513738+3.623292,-1.513738+3.369366,-1.513732+3.623302,-1.513732+3.623170,-1.513314+3.623292,-1.513314+3.369366]
p4_2s = [-0.879497+4.767774,-0.879496+3.971614,-0.879483+4.767774]
p3_2s = [-1.500370+3.971614]
p2_2s = [-3.623302+4.767774,-3.623292+3.971614,-3.623170+4.767774,-3.369366+3.971614]

s4_3p = [-0.913818+1.500370]

def find_wave(eV):
    return (6.58*3/(eV))*10**2

#print([find_wave(x) for x in s_p])
print([find_wave(x) for x in p4_3d])
print([find_wave(x) for x in d4_3p])
#print([find_wave(x) for x in d4_2p])
#print([find_wave(x) for x in d3_2p])
#print([find_wave(x) for x in p4_2s])
#print([find_wave(x) for x in p3_2s])
print([find_wave(x) for x in p2_2s])
print([find_wave(x) for x in s4_3p])
# Out:
# [3112.3423135077865, 3112.3766637971, 3112.4110148446553, 3112.3815710431836]
# [2707.752071965301, 2707.763214748668, 2707.889506036509, 2706.8572345353296]
# [1724.8128394578457, 5667.170032326411, 1724.6139276116455, 3277.7194776902525]
# [3365.430515964484]

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_full.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'sodium_full'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_twin.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'sodium_twin'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)
import two_peak
importlib.reload(two_peak)
import calib
importlib.reload(calib)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('sodium_twin.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])


fit_parameters = two_peak.fit_twin_gaussian(time, value, 5790, 5825)
plt.plot(time, two_peak.twin_gaussian(time, *fit_parameters), color = 'Black', label="fit", linestyle='-')

#plt.plot(time, calib.gaussian(time, fit_parameters[0], fit_parameters[1], fit_parameters[2], fit_parameters[6]), color='Red',
# label=f'Peak 1 {calib.round_sf(fit_parameters[1],5)}', linestyle='--')
#plt.plot(time, calib.gaussian(time, fit_parameters[3], fit_parameters[4], fit_parameters[5], fit_parameters[6]), color='Blue',
# label=f'Peak 2, center = {calib.round_sf(fit_parameters[4],5)} A', linestyle='--')

plt.plot(time, calib.gaussian(time, fit_parameters[0], fit_parameters[1], fit_parameters[2], fit_parameters[6]), color='Red',
         label=f'Peak 1, center = {calib.round_sf(fit_parameters[1], 5)} $\mathrm{{\AA}}$', linestyle='--')

plt.plot(time, calib.gaussian(time, fit_parameters[3], fit_parameters[4], fit_parameters[5], fit_parameters[6]), color='Blue',
         label=f'Peak 2, center = {calib.round_sf(fit_parameters[4], 5)} $\mathrm{{\AA}}$', linestyle='--')


plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'sodium_twin'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quartzbulb_no_I2.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quartzbulb_no_I2'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quar_withI2_nowig'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('output.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'output'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quartzbulb_no_I2.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quartzbulb_no_I2'}')

#plt.xlim(5150, 6250)
#plt.ylim(0.3, 2.4)

#plt.xlim(5630, 5670)
#plt.ylim(1.92, 2.5)

plt.xlim(5600, 6000)
#plt.ylim(1.92, 2.5)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quar_withI2_nowig'}')

#plt.xlim(5150, 6250)
#plt.ylim(0.3, 2.4)

#plt.xlim(5630, 5670)
#plt.ylim(1.92, 2.35)

plt.xlim(5750, 5850)
#plt.ylim(1.2, 1.3)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')

#plt.xlim(5150, 6250)
#plt.ylim(-2.3, 2.8)

#plt.xlim(5630, 5670)
#plt.ylim(-2.2, 0.35)

plt.xlim(5750, 5850)
#plt.ylim(1.92, 2.5)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')

#plt.xlim(5150, 6250)
#plt.ylim(-2.3, 2.8)

plt.xlim(5170, 5350)
plt.ylim(-2.3, 2.8)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')

#plt.xlim(5900, 6150)
#plt.ylim(-1.5, -0.5)

plt.xlim(5900, 5940)
plt.ylim(-1, 1)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()
