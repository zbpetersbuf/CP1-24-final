# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import linregress
from scipy.signal import savgol_filter
import sys

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength Hg line correction {'quar_withI2_nowig'}')

plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(time, value, label=file_path.split('/')[-1])


plt.axvline(x=5196, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5210, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5226, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5242, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5257, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5275, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5293, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5311, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5329, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5349, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5369, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5390, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5412, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5435, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5458, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5482, color='red', linestyle='--', linewidth=2)


plt.axvline(x=5507, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5533, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5559, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5587, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5617, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5647, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5678, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5710, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5741, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5775, color='red', linestyle='--', linewidth=2)


plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for Hg line fit {'quar_withI2_nowig'}')

#plt.xlim(3500, 7000)
#plt.xlim(xmin, xmax)
plt.xlim(5300, 5800)
plt.ylim(1.7, 2.4)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))


for file_path, data in file_contents.items():
    time = [1.106*point[0] + -556.137 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength Hydrogen line correction {'quar_withI2_nowig'}')

plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(time, value, label=file_path.split('/')[-1])


plt.axvline(x=5196, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5210, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5226, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5242, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5257, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5275, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5293, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5311, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5329, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5349, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5369, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5390, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5412, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5435, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5458, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5482, color='red', linestyle='--', linewidth=2)

plt.axvline(x=5507, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5533, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5559, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5587, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5617, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5647, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5678, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5710, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5741, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5775, color='red', linestyle='--', linewidth=2)






plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for Hydrogen line correction {'quar_withI2_nowig'}')

#plt.xlim(3500, 7000)
#plt.xlim(xmin, xmax)
plt.xlim(5300, 5800)
plt.ylim(1.7, 2.4)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))


for file_path, data in file_contents.items():
    time = [point[0] for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength no line correction {'quar_withI2_nowig'}')
plt.ylim(-0.08, -0.02)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(11, 7))
plt.plot(time, value, label=file_path.split('/')[-1])


plt.axvline(x=5196, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5210, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5226, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5242, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5257, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5275, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5293, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5311, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5329, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5349, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5369, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5390, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5412, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5435, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5458, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5482, color='red', linestyle='--', linewidth=2)

plt.axvline(x=5507, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5533, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5559, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5587, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5617, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5647, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5678, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5710, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5741, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5775, color='red', linestyle='--', linewidth=2)






plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for no line correction {'quar_withI2_nowig'}')

#plt.xlim(3500, 7000)
#plt.xlim(xmin, xmax)
plt.xlim(5300, 5800)
plt.ylim(1.7, 2.4)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
xmin = 5100
xmax = 6400
# window_length=2000, polyorder=3
wl = 2000
pol = 3

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

x_avg_start = 100
bin_width = 5

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([1.10608*point[0] + -556.13681 for point in data])
    intensity = np.array([point[1] for point in data])
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)
    plt.plot(wavelength, intensity, label=file_path.split('/')[-1])
    plt.plot(wavelength, smooth_intensity, color='orange', linewidth=1, label='Smoothed Trend')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Intensity vs Wavelength for I2_wiggle')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter  # Don't forget this import!

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([1.10608*point[0] + -556.13681 for point in data])
    intensity = np.array([point[1] for point in data])

    # Apply Savitzky-Golay filter
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)

    # Detrended data = original - smoothed
    detrended_intensity = intensity - smooth_intensity

    # Plot detrended data
    plt.plot(wavelength, detrended_intensity, label='Detrended Signal')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Detrended Intensity')
plt.title('Detrended Spectrum (Original - Smoothed)')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)
#plt.xlim(0.5, -0.5)
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 3

v = np.arange(x,x+36 )
#v = np.arange(30, 26, -1)

w_e, x_e, c= Birge_Sponer.Birge_Sponer_funk(v)

lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
          5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]

#lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          #5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771]


#lamdas = [1.10608*l/0.985 + 35.505 -556.13681 for l in lamdas]
#lamdas = lamdas[::-1]

G_v = [1 / (x * 10**(-8)) for x in lamdas]

v_fit = np.linspace(min(v), max(v), 200)
G_fit = Birge_Sponer.fit_BS(v_fit, w_e, x_e, c)

plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label='Birge-Sponer Fit', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()

print(f"w_e = {w_e:.2f}, w_e*x_e = {x_e:.4f}, w_e*x_e = {w_e*x_e:.4f}")

v_m = 0.5*w_e-1

print(f"v_m = {v_m:.2f}")

G = w_e*(v_m+1/2)-w_e*x_e*((v_m+1/2)**(2))

print(f"equation 7 = {G:.2f}")
# Out:
# w_e = 1252.26, w_e*x_e = 0.0322, w_e*x_e = 40.2691
# v_m = 625.13
# equation 7 = -14978383.15

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 3

v = np.arange(x,x+36 )
#v = np.arange(30, 26, -1)

#w_e, x_e, c= Birge_Sponer.Birge_Sponer_funk_v2(v)

w_e, x_e, c, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)

lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
          5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]


v_fit = np.arange(x,x+36)
i = 0
l = len(lamdas)

G_fit = np.zeros(l-1)

while i<l:
    #G_fit[i] = G_v_1[i]-G_v_1[i+1]
    G_fit[i] = Birge_Sponer.fit_BS_v2(i, w_e, x_e, c) - Birge_Sponer.fit_BS_v2(i+1, w_e, x_e, c)
    i+=1

v = np.arange(x,x+36)
plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label='Birge-Sponer Fit', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()

print(f"w_e = {w_e:.2f}, w_e*x_e = {x_e:.4f}, w_e*x_e = {w_e*x_e:.4f}")

v_m = 0.5*w_e-1

print(f"v_m = {v_m:.2f}")

G = w_e*(v_m+1/2)-w_e*x_e*((v_m+1/2)**(2))

print(f"equation 7 = {G:.2f}")
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 15
#      10 v = np.arange(x,x+36 )
#      11 #v = np.arange(30, 26, -1)
#      12
#      13 #w_e, x_e, c= Birge_Sponer.Birge_Sponer_funk_v2(v)
# ---> 15 w_e, x_e, c, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)
#      17 lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
#      18           5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
#      19           5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]
#      22 v_fit = np.arange(x,x+36)
#
# File /workspaces/CP1-24-final/zbpetersbuf/advlab3/Birge_Sponer.py:90, in Birge_Sponer_funk_v2(v)
#      88 w_e_guess = 197.99
#      89 x_e_guess = 0.0020
# ---> 90 popt, _ = curve_fit(fit_BS_v2, v, G_v, p0=[w_e_guess, x_e_guess])
#      91 w_e = popt[0]
#      92 x_e=popt[1]
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:1014, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1011 if ydata.size != 1 and n > ydata.size:
#    1012     raise TypeError(f"The number of func parameters={n} must not"
#    1013                     f" exceed the number of data points={ydata.size}")
# -> 1014 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1015 popt, pcov, infodict, errmsg, ier = res
#    1016 ysize = len(infodict['fvec'])
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:425, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     423 if not isinstance(args, tuple):
#     424     args = (args,)
# --> 425 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     426 m = shape[0]
#     428 if n > m:
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:23, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      21 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      22                 output_shape=None):
# ---> 23     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      24     if (output_shape is not None) and (shape(res) != output_shape):
#      25         if (output_shape[0] != 1):
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:522, in _lightweight_memoizer.<locals>._memoized_func(params)
#     519 elif _memoized_func.last_params is not None:
#     520     _memoized_func.skip_lookup = True
# --> 522 val = f(params)
#     524 if _memoized_func.last_params is None:
#     525     _memoized_func.last_params = np.copy(params)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:539, in _wrap_func.<locals>.func_wrapped(params)
#     538 def func_wrapped(params):
# --> 539     return func(xdata, *params) - ydata
#
# ValueError: operands could not be broadcast together with shapes (36,) (35,)

# %%
print(len(v))
print(len(G_v))
# Out:
# 36
# 36

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 3

v = np.arange(x,x+35)
#v = np.arange(30, 26, -1)

w_e, x_e, c, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)

lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
          5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]

#lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          #5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771]


#lamdas = [1.10608*l/0.985 + 35.505 -556.13681 for l in lamdas]
#lamdas = lamdas[::-1]

plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
#plt.plot(v_fit, G_fit, label='Birge-Sponer Fit', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 13
#      10 v = np.arange(x,x+35)
#      11 #v = np.arange(30, 26, -1)
# ---> 13 w_e, x_e, c, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)
#      15 lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
#      16           5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
#      17           5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]
#      19 #lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
#      20           #5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771]
#      21
#      22
#      23 #lamdas = [1.10608*l/0.985 + 35.505 -556.13681 for l in lamdas]
#      24 #lamdas = lamdas[::-1]
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
print(len(v))
print(len(G_v))
# Out:
# 35
# 36

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 15

v = np.arange(x,x+35)
#v = np.arange(30, 26, -1)

w_e, x_e, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)

lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
          5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]

#lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          #5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771]


#lamdas = [1.10608*l/0.985 + 35.505 -556.13681 for l in lamdas]
#lamdas = lamdas[::-1]

#G_v = [1 / (x * 10**(-8)) for x in lamdas]

v_fit = np.linspace(min(v), max(v), 200)

G_fit = Birge_Sponer.fit_BS_v2(v_fit, w_e, x_e)

print(f"Linear Fit Equation: delta_G = {w_e:.5f} - 2 * {w_e:.5f}*{x_e:.5f}*(v+1)")


plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label='Birge-Sponer Fit', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()

print(f"w_e = {w_e:.2f}, x_e = {x_e:.4f}, w_e*x_e = {w_e*x_e:.4f}")

v_m = 0.5*w_e-1

print(f"v_m = {v_m:.2f}")

G = w_e*(v_m+1/2)-w_e*x_e*((v_m+1/2)**(2))

print(f"equation 7 = {G:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 import sys
#       8 x = 15
# ---> 10 v = np.arange(x,x+35)
#      11 #v = np.arange(30, 26, -1)
#      13 w_e, x_e, G_v = Birge_Sponer.Birge_Sponer_funk_v2(v)
#
# NameError: name 'np' is not defined

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

last_wiggle_G = - 1 / (6112 * 10**(-8)) + 1 / (6075 * 10**(-8))

print(Birge_Sponer.fit_BS_v2(x,w_e,x_e))
print(last_wiggle_G)

v_00 = Birge_Sponer.fit_BS_v2(x+35,w_e,x_e)

print(f"v_00 = {v_00:.2f}")

print(f"v_00 = {1 / (6112 * 10**(-8)):.2f}")
# Out:
# 105.88284670849288
# 99.64880529162292
# v_00 = 51.49
# v_00 = 16361.26

# %%
D_dubprim = 16361.26 + 5336.61 - 7589

print(f"D_dubprim = {D_dubprim:.9f}")
# Out:
# D_dubprim = 14108.870000000
