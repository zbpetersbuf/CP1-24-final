# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import linregress
from scipy.signal import savgol_filter

# %%
print(1+1)
# Out:
# 2

# %%
import importlib
import spectrum
importlib.reload(spectrum)
import calib
importlib.reload(calib)
import sys

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quartzbulb_no_I2.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quartzbulb_no_I2'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quar_withI2_nowig'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('output.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'output'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quartzbulb_no_I2.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quartzbulb_no_I2'}')

#plt.xlim(5150, 6250)
#plt.ylim(0.3, 2.4)

#plt.xlim(5630, 5670)
#plt.ylim(1.92, 2.5)

plt.xlim(5600, 6000)
#plt.ylim(1.92, 2.5)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quar_withI2_nowig.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quar_withI2_nowig'}')

#plt.xlim(5150, 6250)
#plt.ylim(0.3, 2.4)

#plt.xlim(5630, 5670)
#plt.ylim(1.92, 2.35)

plt.xlim(5200, 5500)
#plt.ylim(1.2, 1.3)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')

#plt.xlim(5150, 6250)
#plt.ylim(-2.3, 2.8)

#plt.xlim(5630, 5670)
#plt.ylim(-2.2, 0.35)

#plt.xlim(5750, 5850)
#plt.ylim(1.92, 2.5)

plt.xlim(5200, 5500)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')

#plt.xlim(5150, 6250)
#plt.ylim(-2.3, 2.8)

plt.xlim(5170, 5350)
plt.ylim(-2.3, 2.8)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.99*point[0] + 35.5 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')

#plt.xlim(5900, 6150)
#plt.ylim(-1.5, -0.5)

#plt.xlim(5000, 5780)
plt.xlim(5540, 5580)
plt.ylim(-0.5, 2.5)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import spectrum
importlib.reload(spectrum)

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = spectrum.read_files('quartzbulb_no_I2.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.985*point[0] + 35.505 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'quartzbulb_no_I2'}')
plt.xlim(5370, 5500)
plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)
importlib.reload(calib)
import sys

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [0.98489*point[0] + 335.50471 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')
plt.xlim(3500, 7000)
plt.legend()
plt.grid(True)
plt.show()

# %%
#window
#xmin = 3500
#xmax = 7000
xmin = 5100
xmax = 6300
# window_length=2000, polyorder=3
wl = 2000
pol = 3

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

x_avg_start = 100
bin_width = 5

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([0.98489*point[0] + 35.50471 for point in data])
    intensity = np.array([point[1] for point in data])
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)
    plt.plot(wavelength, intensity, label=file_path.split('/')[-1])
    plt.plot(wavelength, smooth_intensity, color='orange', linewidth=1, label='Smoothed Trend')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Intensity vs Wavelength for I2_wiggle')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([0.985*point[0] + 35.505 for point in data])
    intensity = np.array([point[1] for point in data])

    # Apply Savitzky-Golay filter
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)

    # Detrended data = original - smoothed
    detrended_intensity = intensity - smooth_intensity

    # Plot detrended data
    plt.plot(wavelength, detrended_intensity, label='Detrended Signal')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Detrended Intensity')
plt.title('Detrended Spectrum (Original - Smoothed)')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))

plt.plot(wavelength, detrended_intensity, label='Detrended Signal')

plt.axvline(x=5196, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5210, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5226, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5242, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5257, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5275, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5293, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5311, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5329, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5349, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5369, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5390, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5412, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5435, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5458, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5482, color='red', linestyle='--', linewidth=2)


plt.axvline(x=5507, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5533, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5559, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5587, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5617, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5647, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5678, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5710, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5741, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5775, color='red', linestyle='--', linewidth=2)




plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Detrended Intensity')
plt.title('Detrended Spectrum (Original - Smoothed)')

#plt.xlim(3500, 7000)
#plt.xlim(xmin, xmax)
plt.xlim(5190, 5500)
plt.ylim(-1, 1.5)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 10

v = np.arange(x, x + 36)

# Call your Birge-Sponer function to get parameters
w_e, x_e = Birge_Sponer.Birge_Sponer_funk(v)

# Define G_v (same way it's done in your module)
lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
          5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]

#lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          #5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771]

G_v = [1 / (x * 1e-8) for x in lamdas]

# Define fit function (unless already imported)
def fit_BS(v, w_e, x_e):
    return w_e - 2 * w_e * x_e * (v + 1)

# Generate fit for plotting
v_fit = np.linspace(min(v), max(v), 200)
G_fit = fit_BS(v_fit, w_e, x_e)

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label='Birge-Sponer Fit', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()

# Print results
print(f"ω_e = {w_e:.2f}, x_e = {x_e:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 13
#      10 v = np.arange(x, x + 36)
#      12 # Call your Birge-Sponer function to get parameters
# ---> 13 w_e, x_e = Birge_Sponer.Birge_Sponer_funk(v)
#      15 # Define G_v (same way it's done in your module)
#      16 lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
#      17           5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
#      18           5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# this is with the hydrogen fit line not Hg
# 1.10608x + -556.13681

# %%
import importlib
import absospec
importlib.reload(absospec)
importlib.reload(calib)
import sys

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    time = [1.10608*point[0] + -556.13681 for point in data]
    value = [point[1] for point in data]

    plt.plot(time, value, label=file_path.split('/')[-1])

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title(f'Intensity vs Wavelength for {'I2_wiggle'}')
plt.xlim(3200, 7300)
plt.legend()
plt.grid(True)
plt.show()

# %%
#window
#xmin = 3500
#xmax = 7000
xmin = 5100
xmax = 6400
# window_length=2000, polyorder=3
wl = 2000
pol = 3

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

x_avg_start = 100
bin_width = 5

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([1.10608*point[0] + -556.13681 for point in data])
    intensity = np.array([point[1] for point in data])
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)
    plt.plot(wavelength, intensity, label=file_path.split('/')[-1])
    plt.plot(wavelength, smooth_intensity, color='orange', linewidth=1, label='Smoothed Trend')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Intensity')
plt.title('Intensity vs Wavelength for I2_wiggle')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)

plt.legend()
plt.grid(True)
plt.show()

# %%
import importlib
import absospec
importlib.reload(absospec)
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter  # Don't forget this import!

sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/advlab3data/')

file_contents = absospec.read_files('I2_wiggle.txt')

plt.figure(figsize=(10, 6))

for file_path, data in file_contents.items():
    wavelength = np.array([1.10608*point[0] + -556.13681 for point in data])
    intensity = np.array([point[1] for point in data])

    # Apply Savitzky-Golay filter
    smooth_intensity = savgol_filter(intensity, window_length=wl, polyorder=pol)

    # Detrended data = original - smoothed
    detrended_intensity = intensity - smooth_intensity

    # Plot detrended data
    plt.plot(wavelength, detrended_intensity, label='Detrended Signal')

plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Detrended Intensity')
plt.title('Detrended Spectrum (Original - Smoothed)')

#plt.xlim(3500, 7000)
plt.xlim(xmin, xmax)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))

plt.plot(wavelength, detrended_intensity, label='Detrended Signal')

plt.axvline(x=5196, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5210, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5226, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5242, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5257, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5275, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5293, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5311, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5329, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5349, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5369, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5390, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5412, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5435, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5458, color='red', linestyle='--', linewidth=2)
plt.axvline(x=5482, color='red', linestyle='--', linewidth=2)


plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Detrended Intensity')
plt.title('Detrended Spectrum (Original - Smoothed)')

#plt.xlim(3500, 7000)
#plt.xlim(xmin, xmax)
plt.xlim(5300, 5340)
plt.ylim(-1, 1.5)

plt.legend()
plt.grid(True, which='major', linestyle='-', color='blue', linewidth=1)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', color='red', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(15, 7))
#       3 plt.plot(wavelength, detrended_intensity, label='Detrended Signal')
#       5 plt.axvline(x=5196, color='red', linestyle='--', linewidth=2)
#
# NameError: name 'plt' is not defined

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

x = 3

v = np.arange(x,x+36 )
#v = np.arange(30, 26, -1)

w_e, x_e = Birge_Sponer.Birge_Sponer_funk(v)

lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771, 5801, 5833,
          5866, 5898, 5933, 5968, 6004, 6040, 6075, 6112]

#lamdas = [5224, 5239, 5253, 5267, 5282, 5298, 5314, 5331, 5350, 5368, 5387, 5406, 5428, 5449,
          #5472, 5494, 5519, 5546, 5571, 5597, 5624, 5652, 5680, 5709, 5739, 5771]


#lamdas = [1.10608*l/0.985 + 35.505 -556.13681 for l in lamdas]
#lamdas = lamdas[::-1]

G_v = [1 / (x * 10**(-8)) for x in lamdas]

v_fit = np.linspace(min(v), max(v), 200)
G_fit = Birge_Sponer.fit_BS(v_fit, w_e, x_e)

plt.figure(figsize=(8, 5))
plt.scatter(v, G_v, label='Data', color='blue')
plt.plot(v_fit, G_fit, label='Birge-Sponer Fit', color='orange')
plt.xlabel('Vibrational Quantum Number v')
plt.ylabel('1 / λ (cm⁻¹)')
plt.title('Birge-Sponer Fit')
plt.legend()
plt.grid(True)
plt.show()

print(f"w_e = {w_e:.2f}, w_e*x_e = {x_e:.4f}, w_e*x_e = {w_e*x_e:.4f}")

v_m = 0.5*w_e-1

print(f"v_m = {v_m:.2f}")

G = w_e*(v_m+1/2)-w_e*x_e*((v_m+1/2)**(2))

print(f"equation 7 = {G:.2f}")
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys
# Out:
# w_e = 19718.07, w_e*x_e = 0.0020, w_e*x_e = 40.2691
# v_m = 9858.04
# equation 7 = -3719395698.67

# %%
import importlib
import Birge_Sponer
importlib.reload(Birge_Sponer)
import calib
importlib.reload(calib)
import sys

last_wiggle_G = 1 / (6112 * 10**(-8))

print(fit_BS(x,w_e,x_e))

v_00 = fit_BS(x+35,w_e,x_e)

print(f"v_00 = {v_00:.2f}")
# Out:
# 19395.91894291825
# v_00 = 16577.08

# %%
print(1/(5224*10**(-8)))
print(1/(6112*10**(-8)))
# Out:
# 19142.41960183767
# 16361.256544502618

# %%
h1=(6.62607015*10**(-34))*(100**2)
h2=(4.135667696*10*(-15))*(100**2)

D_dubprim = (h1**2)*w_e/(4*x_e) - w_e/2 - w_e*x_e/4

print(f"D_dubprim = {D_dubprim:.2f}")

E_I = 7589

D_singleprime = D_dubprim - v_00 + 7
# Out:
# D_dubprim = -9869.10
