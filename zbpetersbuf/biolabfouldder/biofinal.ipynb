# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
import bio_1 as bio
#import importlib

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')  # Add path to custom modules
import bio_1 as bio  # Import your bio module (if needed)

exp_name = '047'  # Replace with the experiment name you're using

# Corrected: Call filenamelister directly instead of through the bio module
bio.process_multiple_files(exp_name)  # Process the data files

#print(results)
# Out:
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL16_8_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL10_5y_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL13_7x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL17_9x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL4_2y_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL9_5x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL15_8x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL5_3x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL19_10x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL20_10_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL14_7_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL11_6x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL2_1y_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL3_2x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL8_4y_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL18_9_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL1_1x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL12_6_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL6_3y_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# Error processing file /workspaces/CP1-24-final/zbpetersbuf/biodata/LL7_4x_047.csv: cannot access local variable 'tot_mean' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 exp_name = '047'  # Replace with the experiment name you're using
#       7 # Corrected: Call filenamelister directly instead of through the bio module
# ----> 8 bio.process_multiple_files(exp_name)  # Process the data files
#      10 #print(results)
#
# File /workspaces/CP1-24-final/zbpetersbuf/biolabfouldder/bio_1.py:72, in process_multiple_files(exp_name)
#      69         print(f"Error processing file {file}: {e}")
#      70 #results[file_key] = {'mean': tot_mean/20, 'std_dev': tot_std_dev/20}
#      71 #print(f"Mean: {tot_mean / 20}, Std Dev: {tot_std_dev / 20}")
# ---> 72 a = tot_mean / 20
#      73 b = tot_std_dev / 20
#      74 return a, b
#
# UnboundLocalError: cannot access local variable 'tot_mean' where it is not associated with a value

# %%
print(results[:,0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(results[:,0])
#
# KeyError: (slice(None, None, None), 0)

# %%
print("world")
# Out:
# world
