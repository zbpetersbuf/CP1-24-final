# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
import bio_1 as bio
#import importlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [19], line 5
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 import pandas as pd
#       6 import sys
#       7 sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
exp_name = '047'  # Replace with the experiment name you're using
results = bio.process_multiple_files(exp_name)  # Process the data files

# Print the fitted parameters (mean and std dev) for each file
for file_key, fit_params in results.items():
    print(f"File: {file_key}, Mean: {fit_params['mean']}, Std Dev: {fit_params['std_dev']}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: 'Distance_(microns)'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [18], line 2
#       1 exp_name = '047'  # Replace with the experiment name you're using
# ----> 2 results = bio.process_multiple_files(exp_name)  # Process the data files
#       4 # Print the fitted parameters (mean and std dev) for each file
#       5 for file_key, fit_params in results.items():
#
# File /workspaces/CP1-24-final/zbpetersbuf/biolabfouldder/bio_1.py:45, in process_multiple_files(exp_name)
#      43 results = {}
#      44 for file in files:
# ---> 45     data = np.loadtxt(file, delimiter=',')
#      46     x_data = data[:, 0]
#      47     y_data = data[:, 1]
#
# ...

# %%
print(files)
# Out:
# ['/workspaces/CP1-24-final/zbpetersbuf/biodata/LL8_4_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL11_6_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL16_8_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL13_7_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL2_1_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL1_1_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL19_10_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL15_8_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL20_10_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL9_5_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL14_7_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL10_5_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL3_2_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL18_9_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL17_9_047.csv', '/workspaces/CP1-24-final/zbpetersbuf/biodata/LL6_3_047
# ...
