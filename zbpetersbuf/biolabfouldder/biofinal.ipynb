# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
import bio_1 as bio
#import importlib

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')  # Add path to custom modules
import bio_1 as bio  # Import your bio module (if needed)

exp_name = '047'  # Replace with the experiment name you're using

# Corrected: Call filenamelister directly instead of through the bio module
results = bio.process_multiple_files(exp_name)  # Process the data files

print(results)
# Out:
# {'_4_047': {'mean': np.float64(0.17984920105590113), 'std_dev': np.float64(0.051933926920459235)}, '_6_047': {'mean': np.float64(0.16388571242221042), 'std_dev': np.float64(0.04423437179455816)}, '_8_047': {'mean': np.float64(0.14221659583662868), 'std_dev': np.float64(0.044547273453513135)}, '_7_047': {'mean': np.float64(0.23377186619834095), 'std_dev': np.float64(0.04910755676397266)}, '_10_047': {'mean': np.float64(0.1892802229477472), 'std_dev': np.float64(0.050120575082204744)}, '_5_047': {'mean': np.float64(0.20436732313811853), 'std_dev': np.float64(0.047542962836897774)}, '_x_047': {'mean': np.float64(0.16960049780491063), 'std_dev': np.float64(0.05213758019240815)}, '_2_047': {'mean': np.float64(0.23109948622199736), 'std_dev': np.float64(0.06066637500754903)}, '_y_047': {'mean': np.float64(0.15388497392265177), 'std_dev': np.float64(0.050950267447524934)}, '_9_047': {'mean': np.float64(0.2655546216857015), 'std_dev': np.float64(0.05290446667446312)}, '_3_047': {'mean': np.float64(0.17709782294079682), 'std_dev': np.float64(0.061938204230311246)}}

# %%
print(bio.findmdfromcsv(results[1]))
# Out:
# _6_047

# %%
print("world")
# Out:
# world
