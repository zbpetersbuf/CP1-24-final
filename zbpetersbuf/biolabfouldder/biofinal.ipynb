# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
import bio_1 as bio
#import importlib

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')  # Add path to custom modules
import bio_1 as bio  # Import your bio module (if needed)

exp_name = '047'  # Replace with the experiment name you're using

# Corrected: Call filenamelister directly instead of through the bio module
bio.process_multiple_files(exp_name)  # Process the data files

#print(results)
# Out:
# {'_8_047': {'mean': np.float64(0.11863676042707831),
#   'std_dev': np.float64(0.04061242349593176)},
#  '_5y_047': {'mean': np.float64(0.20436732313811853),
#   'std_dev': np.float64(0.047542962836897774)},
#  '_7x_047': {'mean': np.float64(0.1167687876623069),
#   'std_dev': np.float64(0.041242832298104014)},
#  '_9x_047': {'mean': np.float64(0.2655546216857015),
#   'std_dev': np.float64(0.05290446667446312)},
#  '_2y_047': {'mean': np.float64(0.23109948622199736),
#   'std_dev': np.float64(0.06066637500754903)},
#  '_5x_047': {'mean': np.float64(0.1314962251072191),
#   'std_dev': np.float64(0.04698964715802749)},
#  '_8x_047': {'mean': np.float64(0.14221659583662868),
#   'std_dev': np.float64(0.044547273453513135)},
#  '_3x_047': {'mean': np.float64(0.17709782294079682),
#   'std_dev': np.float64(0.061938204230311246)},
#  '_10x_047': {'mean': np.float64(0.21282861119504942),
#   'std_dev': np.float64(0.055212986157270265)},
#  '_10_047': {'mean': np.float64(0.1892802229477472),
#   'std_dev': np.float64(0.050120575082204744)},
#  '_7_047': {'mean': np.float64(0.23377186619834095),
#   'std_dev': np.float64(0.04910755676397266)},
#  '_6x_047': {'mean': np.float64(0.1745218672071184),
#   'std_dev': np.float64(0.04569801676298555)},
#  '_1y_047': {'mean': np.float64(0.15388497392265177),
#   'std_dev': np.float64(0.050950267447524934)},
#  '_2x_047': {'mean': np.float64(0.2103889787679641),
#   'std_dev': np.float64(0.053386599912567424)},
#  '_4y_047': {'mean': np.float64(0.15820925329425375),
#   'std_dev': np.float64(0.046488236418432166)},
#  '_9_047': {'mean': np.float64(0.2877547019195595),
#   'std_dev': np.float64(0.04895331868424856)},
#  '_1x_047': {'mean': np.float64(0.16960049780491063),
#   'std_dev': np.float64(0.05213758019240815)},
#  '_6_047': {'mean': np.float64(0.16388571242221042),
#   'std_dev': np.float64(0.04423437179455816)},
#  '_3y_047': {'mean': np.float64(0.14926461423588153),
#   'std_dev': np.float64(0.05390549649100277)},
#  '_4x_047': {'mean': np.float64(0.17984920105590113),
#   'std_dev': np.float64(0.051933926920459235)}}

# %%
print(results[:,0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(results[:,0])
#
# KeyError: (slice(None, None, None), 0)

# %%
print("world")
# Out:
# world
