# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit

# %%
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
import bio_1 as bio
#import importlib

# %%
import importlib
import bio_1
importlib.reload(bio_1)
exp_name = '047'  # Replace with your experiment name
bio_1.process_multiple_files(exp_name)  # Call the updated function from bio_1.py
# Out:
# Means from each file: [np.float64(0.11863676042707831), np.float64(0.20436732313811853), np.float64(0.1167687876623069), np.float64(0.2655546216857015), np.float64(0.23109948622199736), np.float64(0.1314962251072191), np.float64(0.14221659583662868), np.float64(0.17709782294079682), np.float64(0.21282861119504942), np.float64(0.1892802229477472), np.float64(0.23377186619834095), np.float64(0.1745218672071184), np.float64(0.15388497392265177), np.float64(0.2103889787679641), np.float64(0.15820925329425375), np.float64(0.2877547019195595), np.float64(0.16960049780491063), np.float64(0.16388571242221042), np.float64(0.14926461423588153), np.float64(0.17984920105590113)]
# ...

# %%
import importlib
import bio_1
importlib.reload(bio_1)
exp_name = '097'  # Replace with your experiment name
bio_1.process_multiple_files(exp_name)  # Call the updated function from bio_1.py
# Out:
# Means from each file: [np.float64(0.12973856248085533), np.float64(0.13902568459812903), np.float64(0.09320182745952676), np.float64(0.14858179647134687), np.float64(0.13562059431516854), np.float64(0.12039485952878798), np.float64(0.17764722298750477), np.float64(0.11605308070112656), np.float64(0.13456662184266957), np.float64(0.11369406367059563), np.float64(0.12804872046210422), np.float64(0.11266900707673058), np.float64(0.15167566301804067), np.float64(0.1466559586380383), np.float64(0.12203688981824011), np.float64(0.14744530871822786), np.float64(0.12008594721671735), np.float64(0.09298939619773879), np.float64(0.12168249876137721), np.float64(0.10540140786055441)]
# ...

# %%
print("world")
# Out:
# world

# %%
file_path = '/workspaces/CP1-24-final/zbpetersbuf/biodata/FCS_hundert.xlsx'

# Read the Excel file
df = pd.read_excel(file_path, skiprows=2)

# Display the first few rows to check the data
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
file_path = '/workspaces/CP1-24-final/zbpetersbuf/biodata/FlipperFLIM.xlsx'
df = pd.read_excel(file_path, skiprows=1)

# Choose which set you want (0, 1, 2, or 3)
set_number = 3

# Calculate which columns to access
time_col = 2 * set_number
count_col = 2 * set_number + 1

# Print selected columns
print("Time values:")
print(df.iloc[:, time_col])

print("\nCount values:")
print(df.iloc[:, count_col])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import importlib
import bio_1
importlib.reload(bio_1)
bio_1.fcs(1*10**(-4),1.4*10**(-2))
# Out:
# Fitted t_D: 0.025973794109691903
# Fitted t_f: 0.027845375292993496
# Fitted a: 1.9679497756863

# %%
#this is what im getting
D = (0.09*10**(-6))**2/(4*0.02597)

#D = 1.58*10**(-12)
print((2*1000*293*1.38*10**(-23))/(1.9679497756863*D*6*m.pi*1))
# Out:
# 2.7958153879075806e-06

# %%
import importlib
import bio_1
importlib.reload(bio_1)
bio_1.fcs2(0,13)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#this is what im getting
D = (0.05*10**(-6))**2/(4*0.21)

#D = 1.58*10**(-12)
print((2*1000*293*1.38*10**(-23))/(D*0.9195558777766255*6*m.pi*1))
# Out:
# 0.00015676053319743633

# %%
import importlib
import bio_1
importlib.reload(bio_1)
bio_1.fcs3(0,10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#this is what im getting
D = (0.05*10**(-6))**2/(4*0.017655185627291146)

#D = 1.58*10**(-12)
print((2*1000*293*1.38*10**(-23))/(D*0.9195558777766255*6*m.pi*1))
# Out:
# 1.3179220536351785e-05

# %%
D = (0.5*10**(-6))**2/(4*0.017)

print(2*D*6*m.pi*1/(1000*293*1.38*10**(-23)))
# Out:
# 34278002.64472161

# %%
.43/0.1722289963861509
# Out:
# 2.4966759896568536

# %%
D = (0.3*10**(-6))**2/(4*10**(-6))

print((2*D*6*m.pi*1/(1000*293*1.38*10**(-23)))**(-1))
# Out:
# 4.766867384427922e-12

# %%
D = (0.16*10**(-6))**2/(4*7*10**(-5))

print((D*6*m.pi*1/(2*1000*293*1.38*10**(-23)))**(-1))
# Out:
# 4.692385081546237e-09

# %%
(241-161)/241
# Out:
# 0.33195020746887965

# %%
print((0.16*10**(-6))**2/(4*7*10**(-5)))
# Out:
# 9.142857142857142e-11

# %% [markdown]
# Flim

# %%
import importlib
import bio_1
importlib.reload(bio_1)
bio_1.load_decay_set( 0, 3,2.1,15)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
print(1/0.57)
# Out:
# 1.7543859649122808

# %%
print({1,2,3,4,5}//2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 print({1,2,3,4,5}//2)
#
# TypeError: unsupported operand type(s) for //: 'set' and 'int'
