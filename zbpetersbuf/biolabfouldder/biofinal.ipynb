# %%
import os
import math as m
import numpy as np
import matplotlib.pyplot as plt
#import pandas as pd
import sys
sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
import bio_1 as bio
import importlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 8
#       6 import sys
#       7 sys.path.append('/workspaces/CP1-24-final/zbpetersbuf/biolabfouldder')
# ----> 8 import bio_1 as bio
#       9 import importlib
#
# File /workspaces/CP1-24-final/zbpetersbuf/biolabfouldder/bio_1.py:8
#       6 import glob
#       7 import numpy as np
# ----> 8 import pandas as pd
#       9 from scipy.optimize import curve_fit
#      10 #import workinh as wrk
#
# ModuleNotFoundError: No module named 'pandas'

# %%
files = bio.filenamelister('047', '.csv')
